# %% [markdown]
# # Imports + config

# %%
import os
from pathlib import Path
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import OrderedDict

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("DEVICE:", DEVICE)

AUDIO_PT = Path("C:/Users/khodj/Documents/M2_ISI/PFE/Models/Wavt2vec.pt")
VIDEO_PT = Path("C:/Users/khodj/Documents/M2_ISI/PFE/Models/Resnet18.pt")

C:\\Users\\khodj\\Documents\\M2_ISI\\PFE\\Models\\Wavt2vec.pt
# Out:
# DEVICE: cpu

# %% [markdown]
# # Loader robuste pour .pt (modèle complet ou state_dict)

# %%
def load_pt(path: Path, map_location="cpu"):
    obj = torch.load(path, map_location=map_location)
    return obj

audio_obj = load_pt(AUDIO_PT, map_location="cpu")
video_obj = load_pt(VIDEO_PT, map_location="cpu")

type(audio_obj), type(video_obj)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       2     obj = torch.load(path, map_location=map_location)
#       3     return obj
# ----> 5 audio_obj = load_pt(AUDIO_PT, map_location="cpu")
#       6 video_obj = load_pt(VIDEO_PT, map_location="cpu")
#       8 type(audio_obj), type(video_obj)
#
# Cell In[4], line 2, in load_pt(path, map_location)
#       1 def load_pt(path: Path, map_location="cpu"):
# ----> 2     obj = torch.load(path, map_location=map_location)
#       3     return obj
#
# File ~\AppData\Roaming\Python\Python313\site-packages\torch\serialization.py:1484, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1481 if "encoding" not in pickle_load_args.keys():
#    1482     pickle_load_args["encoding"] = "utf-8"
# -> 1484 with _open_file_like(f, "rb") as opened_file:
# ...
